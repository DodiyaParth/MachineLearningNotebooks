# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# /home/saliakvihs/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /home/saliakvihs/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /home/saliakvihs/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /home/saliakvihs/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 216, got 192
#   return f(*args, **kwds)
# /home/saliakvihs/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
iris=sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
print(iris.shape)
print(np.mean(iris[iris.species=='setosa']))
print(np.mean(iris[iris.species=='versicolor']))
print(np.mean(iris[iris.species=='virginica']))
# Out:
# (150, 5)
# sepal_length    5.006
# sepal_width     3.428
# petal_length    1.462
# petal_width     0.246
# dtype: float64
# sepal_length    5.936
# sepal_width     2.770
# petal_length    4.260
# petal_width     1.326
# dtype: float64
# sepal_length    6.588
# sepal_width     2.974
# petal_length    5.552
# petal_width     2.026
# dtype: float64

# %%
print(iris.columns)
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
iris["species"].value_counts()
# Out:
# versicolor    50
# setosa        50
# virginica     50
# Name: species, dtype: int64

# %%
iris.plot(kind='scatter',x='sepal_length',y='sepal_width')

# %%
sns.set_style('whitegrid')
sns.FacetGrid(iris,hue='species',size=8)\
    .map(plt.scatter,"sepal_length","sepal_width")\
    .add_legend()
plt.show()
# Out:
# /home/saliakvihs/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
plt.close()
sns.set_style('whitegrid')
sns.pairplot(iris,hue='species',size=3)
plt.show()
# Out:
# /home/saliakvihs/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)

# %%
iris_setosa=iris.loc[iris['species']=='setosa']
iris_versicolor=iris.loc[iris['species']=='versicolor']
iris_virginica=iris.loc[iris['species']=='virginica']

# %%
sns.FacetGrid(iris,hue='species',height=5)\
    .map(sns.distplot,"petal_length")\
    .add_legend()
plt.show()
plt.close()
sns.FacetGrid(iris,hue='species',height=5)\
    .map(sns.distplot,"petal_width")\
    .add_legend()
plt.show()
plt.close()
sns.FacetGrid(iris,hue='species',height=5)\
    .map(sns.distplot,"sepal_length")\
    .add_legend()
plt.show()
plt.close()
sns.FacetGrid(iris,hue='species',height=5)\
    .map(sns.distplot,"sepal_width")\
    .add_legend()
plt.show()
plt.close()

# %%
sns.boxplot(x='species',y='petal_length',data=iris)
plt.plot()
# Out:
# []

# %%
sns.violinplot(x='species',y='petal_length',data=iris)
plt.show()

# %%
sns.jointplot(x='petal_length',y='petal_width',data=iris_setosa,kind='kde')
plt.show()
